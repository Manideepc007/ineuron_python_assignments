# %% [markdown]
# ### 1. In what modes should the PdfFileReader() and PdfFileWriter() File objects will be opened?

# %%
## These files will be opened in binary mode.
## read binary (rb) for PdfFileReader() and write binary (wb) PdfFileWriter()

# %% [markdown]
# ### 2. From a PdfFileReader object, how do you get a Page object for page 5?

# %%
## Calling getPage(4) will return a Page object for page 5

# %%
import PyPDF2 as pdf
a=pdf.PdfFileReader('D:/General/Rich-Dad-Poor-Dad.pdf')
((a.getPage(20)))
# Out:
# {'/Type': '/Page',
#  '/Parent': {'/Type': '/Pages',
#   '/Count': 220,
#   '/Kids': [IndirectObject(4, 0),
#    IndirectObject(8, 0),
#    IndirectObject(17, 0),
#    IndirectObject(31, 0),
#    IndirectObject(46, 0),
#    IndirectObject(51, 0),
#    IndirectObject(60, 0),
#    IndirectObject(67, 0),
#    IndirectObject(76, 0),
#    IndirectObject(86, 0),
#    IndirectObject(105, 0),
#    IndirectObject(119, 0),
#    IndirectObject(134, 0),
#    IndirectObject(156, 0),
#    IndirectObject(168, 0),
#    IndirectObject(176, 0),
#    IndirectObject(184, 0),
#    IndirectObject(197, 0),
#    IndirectObject(205, 0),
#    IndirectObject(214, 0),
#    IndirectObject(221, 0),
#    IndirectObject(228, 0),
#    IndirectObject(242, 0),
#    IndirectObject(251, 0),
#    IndirectObject(258, 0),
#    IndirectObject(265, 0),
#    IndirectObject(274, 0),
#    IndirectObject(280, 0),
#    IndirectObject(289, 0),
#    IndirectObject(296, 0),
#    IndirectObject(308, 0),
#    IndirectObject(316, 0),
# ...

# %% [markdown]
# ### 3. What PdfFileReader variable stores the number of pages in the PDF document?

# %%
## The PdfFileReader.numPages variable stores an integer of the number of pages in the PdfFileReader object

# %%
a=pdf.PdfFileReader(r'D:/General/Rich-Dad-Poor-Dad.pdf')
a.numPages
# Out:
# 220

# %% [markdown]
# ### 4. If a PdfFileReader object’s PDF is encrypted with the password swordfish, what must you do before you can obtain Page objects from it?

# %%
## before we obtain the page object, the pdf has to be decrypted by calling .decrypt('swordfish')

# %%
#pdfReader.decrypt('swordfish')

# %% [markdown]
# ### 5. What methods do you use to rotate a page?

# %%
## The rotateClockwise() and rotateCounterClockwise() methods. The degrees to rotate is passed as an integer argument

# %%
#pageObj.rotateClockwise(180)

# %% [markdown]
# ### 6. What is the difference between a Run object and a Paragraph object?

# %% [markdown]
# Paragraph Object :  A document contains multiple paragraphs. A paragraph begins on a new line and contains multiple
# runs.
# The Document object contains a list of Paragraph objects for the paragraphs in the document. (A new paragraph begins
# whenever the user presses ENTER or RETURN while typing in a Word document.)
#
# Run Objects :
# Runs are contiguous groups of characters within a paragraph with the same style

# %% [markdown]
# ### 7. How do you obtain a list of Paragraph objects for a Document object that’s stored in a variable named doc?

# %%
## By using doc.paragraphs

# %%
pip install python-docx
# Out:
# ...
#   Created wheel for python-docx: filename=python_docx-0.8.11-py3-none-any.whl size=184605 sha256=63d6e84b6e4f7043518d839d9f5d07f61563c783492a67de1b44d11d5908e78e
#   Stored in directory: c:\users\manim\appdata\local\pip\cache\wheels\32\b8\b2\c4c2b95765e615fe139b0b17b5ea7c0e1b6519b0a9ec8fb34d
# Successfully built python-docx
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import docx
doc = docx.Document(r'D:/Office/Office Tools/AGUSTA - COLOR SEQUENCE FOR BLADES.docx')
doc.paragraphs

# %% [markdown]
# ### 8. What type of object has bold, underline, italic, strike, and outline variables?

# %%
### A Run object has bold, underline,italic,strike and outline variables

# %%
# import docx
# doc_para=docx.Document(PATH)
# # doc_para.add_run('BOLD').bold = True
# # doc_para.add_run('ITALIC').italic = True
# doc_para.add_run('STRIKE').strike = True
# doc_para.add_run(', and ')

# %% [markdown]
# ### 9. What is the difference between False, True, and None for the bold variable?

# %% [markdown]
# Runs can be further styled using text attributes. Each attribute can be set to one of three values:
# True (the attribute is always enabled, no matter what other styles are applied to the run),
# False (the attribute is always disabled),
# None (defaults to whatever the run’s style is set to)
#
# True always makes the Run object bolded and False makes it always not bolded, no matter what the style’s bold setting is. None will make the Run object just use the style’s bold setting

# %% [markdown]
# ### 10. How do you create a Document object for a new Word document?

# %%
## By Calling the docx.Document() function.

# %%
import docx
doc = docx.Document(r'D:/Office/Office Tools/AGUSTA - COLOR SEQUENCE FOR BLADES.docx')
doc

# %% [markdown]
# ### 11. How do you add a paragraph with the text 'Hello, there!' to a Document object stored in a variable named doc?

# %%
import docx
doc = docx.Document()

doc.add_paragraph('Hello there!')
doc.save('hellothere.docx')

# %% [markdown]
# ### 12. What integers represent the levels of headings available in Word documents?

# %% [markdown]
# integer from 0 to 4
#
# The arguments to add_heading() are a string of the heading text and an integer from 0 to 4. The integer 0 makes the heading the Title style, which is used for the top of the document. Integers 1 to 4 are for various heading levels, with 1 being the main heading and 4 the lowest subheading
